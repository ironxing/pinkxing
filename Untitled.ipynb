# %% [markdown]
# # testing

# %% [markdown]
# yi hang zi

# %%
import pandas as pd
import numpy as np
import csv

# %%
data = {'Country': ['Sweden', 'India', 'Italy'], 
       'Capital': ['Stockholm', 'New Delhi', 'Rome']}
dataframe = pd.DataFrame(data, columns= ['Country','Capital'])
print(dataframe)
# Out:
#   Country    Capital
# 0  Sweden  Stockholm
# 1   India  New Delhi
# 2   Italy       Rome

# %%
dataframe.to_csv('country_profile.csv',sep=',')

# %%
pd.read_csv('trees.csv')
# Out:
#     Index   "Girth (in)"   "Height (ft)"   "Volume(ft^3)"
# 0       1            8.3              70             10.3
# 1       2            8.6              65             10.3
# 2       3            8.8              63             10.2
# 3       4           10.5              72             16.4
# 4       5           10.7              81             18.8
# 5       6           10.8              83             19.7
# 6       7           11.0              66             15.6
# 7       8           11.0              75             18.2
# 8       9           11.1              80             22.6
# 9      10           11.2              75             19.9
# 10     11           11.3              79             24.2
# 11     12           11.4              76             21.0
# 12     13           11.4              76             21.4
# 13     14           11.7              69             21.3
# 14     15           12.0              75             19.1
# ...

# %%
pd.read_csv('csv_sample.csv')
# Out:
#        id                    name  gender      dates  yearOfBirth  \
# 0   10093  Abakanowicz, Magdalena  Female  born 1930         1930
# 1       0     Abbey, Edwin Austin    Male  1852–1911         1852
# 2    2756        Abbott, Berenice  Female  1898–1991         1898
# 3       1  Abbott, Lemuel Francis    Male  1760–1803         1760
# 4     622          Abrahams, Ivor    Male  born 1935         1935
# 5    2606                 Absalon    Male  1964–1993         1964
# 6    9550             Abts, Tomma  Female  born 1967         1967
# 7     623           Acconci, Vito    Male  born 1940         1940
# 8     624          Ackling, Roger    Male  1947–2014         1947
# 9     625         Ackroyd, Norman    Male  born 1938         1938
# 10   2411            Adam, Robert    Male  1728–1792         1728
# 11    626    Adams, Harry William    Male  1868–1947         1868
# 12    627           Adams, Norman    Male  1927–2005         1927
# ...

# %%
pd.read_csv('temp.csv', index_col=0, quoting = csv.QUOTE_ALL)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.read_csv('KU0101A5.csv', index_col=0, sep=';', encoding='latin_1')
# Out:
#                                                    typ av kostnad   2000  \
# region
# 0114 Upplands Väsby                                mediekostnader   1174
# 0114 Upplands Väsby  personalkostnader för biblioteksverksamheten   4927
# 0114 Upplands Väsby         lokalkostnader (inkl. hyra, städning)    855
# 0114 Upplands Väsby                              övriga kostnader   1559
# 0114 Upplands Väsby                          investeringsutgifter     ..
# 0115 Vallentuna                                    mediekostnader    800
# 0115 Vallentuna      personalkostnader för biblioteksverksamheten   2970
# 0115 Vallentuna             lokalkostnader (inkl. hyra, städning)   1123
# 0115 Vallentuna                                  övriga kostnader   1072
# 0115 Vallentuna                              investeringsutgifter     ..
# 0117 Österåker                                     mediekostnader    794
# 0117 Österåker       personalkostnader för biblioteksverksamheten   3730
# ...
